# %%
{r}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a403186c089a> in <module>()
# ----> 1 {r}
#
# NameError: name 'r' is not defined
